# %% [markdown]
# #  Lets Finetune some well know architectures

# %% [markdown]
# ## I) Convolutional architectures

# %% [markdown]
# ### 1) Resnet50

# %%
# !python main.py --data_train C:/Users/frank/Desktop/TU_berlin/train --data_val C:/Users/frank/Desktop/TU_berlin/val --model model.py --model_name resnet50 --epochs 1
# Out:
# Model names: ['resnet50']
# Model: resnet50, Epoch: 0, Training Loss: 5.450080231444477, Validation Loss: 5.253854487804657, Accuracy: 0.034666666666666665
# Best model for resnet50 saved with accuracy: 0.034666666666666665
# c:\Users\frank\Sketch-classification\.venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\frank\Sketch-classification\.venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names resnet50
# Out:
# Global Accuracy: 0.00
#
# Top 5 Best Performing Classes:
# Class airplane: Accuracy 1.00
# Class alarm clock: Accuracy 0.00
# Class angel: Accuracy 0.00
# Class ant: Accuracy 0.00
# Class apple: Accuracy 0.00
#
# Top 5 Worst Performing Classes:
# Class alarm clock: Accuracy 0.00
# Class angel: Accuracy 0.00
# Class ant: Accuracy 0.00
# Class apple: Accuracy 0.00
# Class arm: Accuracy 0.00
# c:\Users\frank\Sketch-classification\.venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\frank\Sketch-classification\.venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#
# 0it [00:00, ?it/s]
# ...

# %% [markdown]
# ### 2) Resnext50

# %%
# !python main.py --data_train C:/Users/frank/Desktop/TU_berlin/train --data_val C:/Users/frank/Desktop/TU_berlin/val --model model.py --model_name resnext50_32x4d --epochs 1

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names resnext50_32x4d

# %% [markdown]
# ### 3) efficientnet_b3

# %%
# !python main.py --data_train C:/Users/frank/Desktop/TU_berlin/train --data_val C:/Users/frank/Desktop/TU_berlin/val --model model.py --model_name efficientnet_b3 --epochs 1

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names efficientnet_b3

# %% [markdown]
# ## II) Vision transformers Architectures

# %% [markdown]
# ### 1) ViT

# %%
# !python main.py --data_train C:/Users/frank/Desktop/TU_berlin/train --data_val C:/Users/frank/Desktop/TU_berlin/val --model model.py --model_name vit --epochs 1

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names vit

# %% [markdown]
# ### 2) Shift Window transformers (SwinT)

# %%
# !python main.py --data_train C:/Users/frank/Desktop/TU_berlin/train --data_val C:/Users/frank/Desktop/TU_berlin/val --model model.py --model_name swin --epochs 1

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names swin

# %% [markdown]
# ### 3) DEiT

# %%
# !python main.py --data_train C:/Users/frank/Desktop/TU_berlin/train --data_val C:/Users/frank/Desktop/TU_berlin/val --model model.py --model_name deit --epochs 1

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names deit

# %% [markdown]
# ### III) Ensemble methods

# %%
# !python evaluate.py --data C:/Users/frank/Desktop/TU_berlin/test --model_names resnet50 resnext50 efficientnet_b3 deit vit swin
